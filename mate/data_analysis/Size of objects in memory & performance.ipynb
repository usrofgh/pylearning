# %%
import numpy as np
import sys

# %%
sys.getsizeof(10)  # 28 bytes
# Out:
# 28

# %%
sys.getsizeof(10 ** 100)
# Out:
# 72

# %%
np.dtype(int).itemsize
# Out:
# 4

# %%
np.dtype(np.int8).itemsize
# Out:
# 1

# %%
import random
arr = [random.randint(1_000, 1_000_000) for _ in range(1000000)]
arr
# Out:
# [171121,
#  547843,
#  415931,
#  383670,
#  760654,
#  866395,
#  641800,
#  296900,
#  19474,
#  696279,
#  492951,
#  376705,
#  17888,
#  119943,
#  942919,
#  847065,
#  576203,
#  130579,
#  575497,
#  142989,
#  155458,
#  981469,
#  472056,
#  660620,
#  426993,
#  38833,
#  329832,
#  875131,
#  332841,
#  932973,
#  479761,
#  712551,
#  22016,
#  595615,
#  607070,
#  536174,
#  67693,
#  369870,
#  345817,
#  65255,
#  133697,
#  570147,
#  190172,
#  218919,
#  19345,
#  167413,
#  160045,
#  269305,
#  746675,
#  564469,
#  540878,
#  107431,
#  627398,
#  237948,
#  57407,
#  237081,
#  69684,
#  520459,
#  305907,
#  794885,
#  721151,
#  273112,
#  521330,
#  36969,
#  111926,
#  789303,
#  403638,
#  374253,
#  99530,
#  155102,
#  510158,
#  266830,
#  829482,
#  142531,
#  419811,
#  458817,
#  834193,
#  983033,
#  616224,
#  201959,
#  28255,
#  854458,
#  42046,
#  214255,
#  987540,
#  218870,
#  748033,
#  771002,
#  829399,
#  643867,
#  421132,
#  73483,
# ...

# %%
sys.getsizeof(arr)
# Out:
# 8448728

# %%
np_arr = np.array(arr, dtype=np.int64)
np_arr.nbytes
# Out:
# 8000000

# %%
# %time sum(arr)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 23 ms
# 500508998600

# %%
# %time np.sum(np_arr)
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
# 500508998600

# %%
my_array = np.array([1.5, .2, 0, 4])

# %%
my_array
# Out:
# array([1.5, 0.2, 0. , 4. ])

# %%
my_array.dtype
# Out:
# dtype('float64')

# %%
my_array = np.arange(5)
my_array = my_array[[False, True, True, False, True]]

my_array
# Out:
# array([1, 2, 4])

# %%
print(my_array[my_array <= True])
# Out:
# [1]
