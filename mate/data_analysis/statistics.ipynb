# %%
import numpy as np

# %%
a = np.array([0, 1, 2, 3])

# %%
a.sum() # происходит невероятно быстро, так как все числа в памяти расположены друг за другом, действия суммы расположено на 
# очень низком уровне процессора
# Out:
# 6

# %%
a.mean()
# Out:
# 1.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a.std()
# Out:
# 1.118033988749895

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a.var()
# Out:
# 1.25

# %%
A = np.array([
    [0, 1, 2],
    [3, 4, 5],
    [7, 8, 9]
])

# %%
A
# Out:
# array([[0, 1, 2],
#        [3, 4, 5],
#        [7, 8, 9]])

# %%
A.sum()
# Out:
# 39

# %%
A.mean()
# Out:
# 4.333333333333333

# %%
A.std()
# Out:
# 2.9814239699997196

# %%
A.sum(axis=0)
# Out:
# array([10, 13, 16])

# %%
A.sum(axis=1)
# Out:
# array([ 3, 12, 24])
